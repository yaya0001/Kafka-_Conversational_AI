# %%
from pypdf import PdfReader
from langchain_experimental.text_splitter import SemanticChunker
from langchain_community.embeddings import OllamaEmbeddings
print("hi")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pypdf import PdfReader
#       2 from langchain_experimental.text_splitter import SemanticChunker
#       3 from langchain_community.embeddings import OllamaEmbeddings
#
# ModuleNotFoundError: No module named 'pypdf'

# %%
embeddings = OllamaEmbeddings(model="nomic-embed-text")
lc_semantic_chunker = SemanticChunker(embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 embeddings = OllamaEmbeddings(model="nomic-embed-text")
#       2 lc_semantic_chunker = SemanticChunker(embeddings)
#
# NameError: name 'OllamaEmbeddings' is not defined

# %%
reader = PdfReader("data for RAG/the hunger artist.pdf")
text=""
for page in reader.pages:
    text += page.extract_text()

# %%
lc_semantic_chunks = lc_semantic_chunker.create_documents([text])
print(lc_semantic_chunks)
